# %%
import pandas as pd
df = pd.read_csv('data/clean.csv')
#for testing purposes 
# dfReplays = dfReplays[:100]
# dfReplaysChar = dfReplaysChar[:100]

# %%
dft = df[:1000]
dft.columns
# Out:
# Index([u'Unnamed: 0', u'lenght', u'hourday', u'month', u'mmr1', u'mmr2',
#        u'year', u'date', u'c2', u'c1', u'day', u'replayID', u'mode',
#        u'weekday'],
#       dtype='object')

# %%
#dft.date.loc[:]=pd.to_datetime(dft.date)

# %%
# %matplotlib inline
import seaborn as sns
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
ax = sns.countplot(df.weekday,order=[0,1,2,3,4,5,6])
ax = sns.plt.xticks([0,1,2,3,4,5,6], ["Monday","Tuesday",'Wedesday','Thursday','Friday',"Saturday","Sunday"])

# %%
ax = sns.countplot(df.hourday,order=[i for i in range(24)])
#This is UCT time.

# %%
ax = sns.distplot(df.lenght,kde=False)
ax.set_xlabel('lenght (min.)')

# %%
#check the MMR distribution. 
dftt = dft[:100]

# %%
def mmr(x,t,v):
    for i in range(len(x)):
        t['mmr'+v+str(i)] = x[i]
t = pd.DataFrame()
dftt.mmr1.apply(mmr,args=(t,'1',))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-bed52457664f> in <module>()
#       3         t['mmr'+v+str(i)] = x[i]
#       4 t = pd.DataFrame()
# ----> 5 dftt.mmr1.apply(mmr,t,'1')
#
# /usr/local/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2167             values = lib.map_infer(values, lib.Timestamp)
#    2168
# -> 2169         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2170         if len(mapped) and isinstance(mapped[0], Series):
#    2171             from pandas.core.frame import DataFrame
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62425)()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#     729         raise ValueError("The truth value of a {0} is ambiguous. "
# ...
